# %%
# Dependencies
import pandas as pd
from pathlib import Path

# %%
# Store filepath in a variable
file = Path("Resources/threatened_species.csv")

# %%
# Read our data file with the Pandas library
df = pd.read_csv(file)
df.head() # First 5
# df.tail() # Last 5
# df.sample(5) # Random 5
# Out:
#              Scientific Name                               Common Name  \
# 0           Neophoca cinerea  Australian Sea-lion, Australian Sea Lion
# 1           Mirounga leonina                    Southern Elephant Seal
# 2  Pseudomys novaehollandiae                New Holland Mouse, Pookila
# 3      Balaenoptera borealis                                 Sei Whale
# 4      Balaenoptera musculus                                Blue Whale
#
#   Threatened status   Kingdom     Class           Family         Genus  \
# 0        Vulnerable  Animalia  Mammalia        Otariidae      Neophoca
# 1        Vulnerable  Animalia  Mammalia         Phocidae      Mirounga
# 2        Vulnerable  Animalia  Mammalia          Muridae     Pseudomys
# 3        Vulnerable  Animalia  Mammalia  Balaenopteridae  Balaenoptera
# 4        Endangered  Animalia  Mammalia  Balaenopteridae  Balaenoptera
#
#            Species      Species Author  \
# 0          cinerea        (Peron,1816)
# 1          leonina     (Linnaeus,1758)
# 2  novaehollandiae  (Waterhouse, 1843)
# 3         borealis        Lesson, 1828
# 4         musculus    (Linnaeus, 1758)
#
#                                              Profile Date extracted
# 0  http://www.environment.gov.au/cgi-bin/sprat/pu...    2020-Oct-12
# 1  http://www.environment.gov.au/cgi-bin/sprat/pu...    2020-Oct-12
# 2  http://www.environment.gov.au/cgi-bin/sprat/pu...    2020-Oct-12
# 3  http://www.environment.gov.au/cgi-bin/sprat/pu...    2020-Oct-12
# 4  http://www.environment.gov.au/cgi-bin/sprat/pu...    2020-Oct-12

# %%
# Set new index to Species
df = df.set_index("Species")

# %%
# Get the data contained within the "leonina" row and the "Family" column
df.loc['leonina', 'Family']
# Out:
# 'Phocidae'

# %%
df.iloc[1,5]
# Out:
# 'Phocidae'

# %%
# Get the first five rows of data and the columns from "Common Name" to "Threatened status"
# The problem with using "Species" as the index is that the values are not unique so duplicates are returned
# If there are duplicates and loc is being used, Pandas will return an error
df.loc[['cinerea', 'leonina', 'novaehollandiae', 'borealis', 'musculus'], 
       ['Common Name', 'Threatened status' ]]
# Out:
#                                                        Common Name  \
# Species
# cinerea                   Australian Sea-lion, Australian Sea Lion
# leonina                                     Southern Elephant Seal
# novaehollandiae                         New Holland Mouse, Pookila
# novaehollandiae  Cape Barren Goose (south-western), Recherche C...
# novaehollandiae                              Masked Owl (northern)
# novaehollandiae           Tiwi Masked Owl, Tiwi Islands Masked Owl
# novaehollandiae                     Tasmanian Emu, Emu (Tasmanian)
# novaehollandiae                             Masked Owl (Tasmanian)
# borealis                                                 Sei Whale
# musculus                                                Blue Whale
#
#                 Threatened status
# Species
# cinerea                Vulnerable
# leonina                Vulnerable
# novaehollandiae        Vulnerable
# novaehollandiae        Vulnerable
# novaehollandiae        Vulnerable
# novaehollandiae        Endangered
# novaehollandiae           Extinct
# novaehollandiae        Vulnerable
# borealis               Vulnerable
# musculus               Endangered

# %%
# Using iloc will not find duplicates since a numeric index is always unique
df.iloc[0:5,
       1:3]
# Out:
#                                               Common Name Threatened status
# Species
# cinerea          Australian Sea-lion, Australian Sea Lion        Vulnerable
# leonina                            Southern Elephant Seal        Vulnerable
# novaehollandiae                New Holland Mouse, Pookila        Vulnerable
# borealis                                        Sei Whale        Vulnerable
# musculus                                       Blue Whale        Endangered

# %%
# Using loc to select all rows for `Common Name` and `Threatened Status`
df.loc[:, ['Common Name', 'Threatened status' ]]
# Out:
#                                                        Common Name  \
# Species
# cinerea                   Australian Sea-lion, Australian Sea Lion
# leonina                                     Southern Elephant Seal
# novaehollandiae                         New Holland Mouse, Pookila
# borealis                                                 Sei Whale
# musculus                                                Blue Whale
# ...                                                            ...
# vigens                                     Ammonite Pinwheel Snail
# palfreymani      Pedra Branca Skink,  Pedra Branca Cool-skink, ...
# cucullatus          Hooded Plover (eastern), Eastern Hooded Plover
# lateralis                      Wiliji, West Kimberley Rock-wallaby
# anophthalmus                                     Blind Velvet Worm
#
#                      Threatened status
# Species
# cinerea                     Vulnerable
# leonina                     Vulnerable
# novaehollandiae             Vulnerable
# borealis                    Vulnerable
# musculus                    Endangered
# ...                                ...
# vigens           Critically Endangered
# palfreymani                 Vulnerable
# cucullatus                  Vulnerable
# lateralis                   Vulnerable
# anophthalmus                Endangered
#
# [1896 rows x 2 columns]

# %%
# Not using loc to select specific column
df[['Common Name', 'Threatened status']].head(3)
# Out:
#                                               Common Name Threatened status
# Species
# cinerea          Australian Sea-lion, Australian Sea Lion        Vulnerable
# leonina                            Southern Elephant Seal        Vulnerable
# novaehollandiae                New Holland Mouse, Pookila        Vulnerable

# %%
# Using iloc to select all rows for the second and third columns.
df.iloc[:, 1:3].head(3)

# %%
# Out:
#                                               Common Name Threatened status
# Species
# cinerea          Australian Sea-lion, Australian Sea Lion        Vulnerable
# leonina                            Southern Elephant Seal        Vulnerable
# novaehollandiae                New Holland Mouse, Pookila        Vulnerable

# %%
# The following logic test/conditional statement returns a series of boolean values
df['Threatened status'] == 'Vulnerable'
# Out:
# Species
# cinerea             True
# leonina             True
# novaehollandiae     True
# borealis            True
# musculus           False
#                    ...
# vigens             False
# palfreymani         True
# cucullatus          True
# lateralis           True
# anophthalmus       False
# Name: Threatened status, Length: 1896, dtype: bool

# %%
# loc will allow for conditional statements to filter rows of data
# using loc on the logic test above only returns rows where the result is True
df.loc[df['Threatened status'] == 'Vulnerable']
# Out:
#                                     Scientific Name  \
# Species
# cinerea                            Neophoca cinerea
# leonina                            Mirounga leonina
# novaehollandiae           Pseudomys novaehollandiae
# borealis                      Balaenoptera borealis
# physalus                      Balaenoptera physalus
# ...                                             ...
# exulans                            Diomedea exulans
# robustus            Osphranter robustus isabellinus
# palfreymani               Carinascincus palfreymani
# cucullatus          Thinornis cucullatus cucullatus
# lateralis        Petrogale lateralis kimberleyensis
#
#                                                        Common Name  \
# Species
# cinerea                   Australian Sea-lion, Australian Sea Lion
# leonina                                     Southern Elephant Seal
# novaehollandiae                         New Holland Mouse, Pookila
# borealis                                                 Sei Whale
# physalus                                                 Fin Whale
# ...                                                            ...
# exulans                                        Wandering Albatross
# robustus                Barrow Island Wallaroo, Barrow Island Euro
# palfreymani      Pedra Branca Skink,  Pedra Branca Cool-skink, ...
# cucullatus          Hooded Plover (eastern), Eastern Hooded Plover
# lateralis                      Wiliji, West Kimberley Rock-wallaby
#
#                 Threatened status   Kingdom     Class           Family  \
# Species
# cinerea                Vulnerable  Animalia  Mammalia        Otariidae
# leonina                Vulnerable  Animalia  Mammalia         Phocidae
# novaehollandiae        Vulnerable  Animalia  Mammalia          Muridae
# borealis               Vulnerable  Animalia  Mammalia  Balaenopteridae
# physalus               Vulnerable  Animalia  Mammalia  Balaenopteridae
# ...                           ...       ...       ...              ...
# exulans                Vulnerable  Animalia      Aves      Diomedeidae
# robustus               Vulnerable  Animalia  Mammalia     Macropodidae
# palfreymani            Vulnerable  Animalia  Reptilia        Scincidae
# cucullatus             Vulnerable  Animalia      Aves     Charadriidae
# lateralis              Vulnerable  Animalia  Mammalia     Macropodidae
#
#                          Genus      Species Author  \
# Species
# cinerea               Neophoca        (Peron,1816)
# leonina               Mirounga     (Linnaeus,1758)
# novaehollandiae      Pseudomys  (Waterhouse, 1843)
# borealis          Balaenoptera        Lesson, 1828
# physalus          Balaenoptera    (Linnaeus, 1758)
# ...                        ...                 ...
# exulans               Diomedea       Linnaeus,1758
# robustus            Osphranter                   -
# palfreymani      Carinascincus    (Rawlinson,1974)
# cucullatus           Thinornis    (Vieillot, 1818)
# lateralis            Petrogale                   -
#
#                                                            Profile  \
# Species
# cinerea          http://www.environment.gov.au/cgi-bin/sprat/pu...
# leonina          http://www.environment.gov.au/cgi-bin/sprat/pu...
# novaehollandiae  http://www.environment.gov.au/cgi-bin/sprat/pu...
# borealis         http://www.environment.gov.au/cgi-bin/sprat/pu...
# physalus         http://www.environment.gov.au/cgi-bin/sprat/pu...
# ...                                                            ...
# exulans          http://www.environment.gov.au/cgi-bin/sprat/pu...
# robustus         http://www.environment.gov.au/cgi-bin/sprat/pu...
# palfreymani      http://www.environment.gov.au/cgi-bin/sprat/pu...
# cucullatus       http://www.environment.gov.au/cgi-bin/sprat/pu...
# lateralis        http://www.environment.gov.au/cgi-bin/sprat/pu...
#
#                 Date extracted
# Species
# cinerea            2020-Oct-12
# leonina            2020-Oct-12
# novaehollandiae    2020-Oct-12
# borealis           2020-Oct-12
# physalus           2020-Oct-12
# ...                        ...
# exulans            2020-Oct-12
# robustus           2020-Oct-12
# palfreymani        2020-Oct-12
# cucullatus         2020-Oct-12
# lateralis          2020-Oct-12
#
# [791 rows x 10 columns]

# %%
# Print the unique values in a specified column
df['Threatened status'].unique()
# Out:
# array(['Vulnerable', 'Endangered', 'Critically Endangered', 'Extinct',
#        'Extinct in the wild', 'Conservation Dependent'], dtype=object)

# %%
# iloc will also allow for conditional statements to filter rows of data
# Using iloc on the logic test above only returns rows where the result is True
df[df.iloc[:, 2] == 'Extinct in the wild']
# Out:
#                   Scientific Name      Common Name    Threatened status  \
# Species
# pedderensis  Galaxias pedderensis  Pedder Galaxias  Extinct in the wild
#
#               Kingdom           Class      Family     Genus  \
# Species
# pedderensis  Animalia  Actinopterygii  Galaxiidae  Galaxias
#
#                 Species Author  \
# Species
# pedderensis  Frankenberg, 1968
#
#                                                        Profile Date extracted
# Species
# pedderensis  http://www.environment.gov.au/cgi-bin/sprat/pu...    2020-Oct-12

# %%
# Multiple conditions can be set to narrow down or widen the filter
df.iloc[(df['Threatened status'] == 'Critically Endangered') &
       (df['Class'] == 'Mammalia') |
       (df['Class'] == 'Amphibia')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 2
#       1 # Multiple conditions can be set to narrow down or widen the filter
# ----> 2 df.iloc[(df['Threatened status'] == 'Critically Endangered') &
#       3        (df['Class'] == 'Mammalia') |
#       4        (df['Class'] == 'Amphibia')]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1642, in _iLocIndexer._getitem_axis(self, key, axis)
#    1639     key = np.asarray(key)
#    1641 if com.is_bool_indexer(key):
# -> 1642     self._validate_key(key, axis)
#    1643     return self._getbool_axis(key, axis=axis)
#    1645 # a list of integers
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1487, in _iLocIndexer._validate_key(self, key, axis)
#    1481         if key.index.inferred_type == "integer":
#    1482             raise NotImplementedError(
#    1483                 "iLocation based boolean "
#    1484                 "indexing on an integer type "
#    1485                 "is not available"
#    1486             )
# -> 1487         raise ValueError(
#    1488             "iLocation based boolean indexing cannot use "
#    1489             "an indexable as a mask"
#    1490         )
#    1491     return
#    1493 if isinstance(key, slice):
#
# ValueError: iLocation based boolean indexing cannot use an indexable as a mask
